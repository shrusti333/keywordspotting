"Yeah," Alex agreed. "Life is full of little wonders if you just take the time to notice them."

By the time they reached their houses, night had fallen. "That was a great day," Jamie said. "We should do this more often."

"Absolutely," Alex replied. "Next time, maybe we can camp overnight."

"Sounds like a plan."

As Alex entered his house, he felt a deep sense of satisfaction. He had learned, explored, and most importantly, enjoyed the moment. His cat greeted him at the door, rubbing against his leg. "Hey there, buddy. Did you miss me?"

He walked over to his bed, exhausted but happy. "Today was perfect," he thought, closing his eyes. And with that, he drifted into a peaceful sleep, dreaming of the next great adventure that awaited.
"""

tts = gTTS(text=script_text, lang='en', slow=False)
tts.save("keyword_new_spotting_script_2000.mp3")

print("Audio saved as keyword_spotting_script.mp3")
# Out:
# Audio saved as keyword_spotting_script.mp3

# %%
import os
from gtts import gTTS

# Ensure the output directory exists
output_dir = "keyword_samples"
os.makedirs(output_dir, exist_ok=True)

# List of keywords
keywords = [
    "backward", "bed", "bird", "cat", "dog", "down", "eight", "five", "follow", 
    "forward", "four", "go", "happy", "house", "learn", "left", "marvin", "nine", 
    "no", "off", "on", "one", "right", "seven", "six", "stop", "three", "tree", 
    "two", "up", "visual", "wow", "yes", "zero", "open", "close", "light", "dark", 
    "fast", "slow", "start", "stop", "jump", "run", "walk", "sit", "stand", "turn", 
    "hello", "goodbye", "morning", "night", "red", "blue", "green", "yellow"
]

# Generate MP3 for each keyword
for keyword in keywords:
    print(f"🔊 Generating MP3 for: {keyword}")
    tts = gTTS(text=keyword, lang='en', slow=False)
    mp3_path = os.path.join(output_dir, f"{keyword}.mp3")
    tts.save(mp3_path)

print("\n✅ All MP3 files saved in 'keyword_samples/'.")
# Out:
# 🔊 Generating MP3 for: backward
# 🔊 Generating MP3 for: bed
# 🔊 Generating MP3 for: bird
# 🔊 Generating MP3 for: cat
# 🔊 Generating MP3 for: dog
# 🔊 Generating MP3 for: down
# 🔊 Generating MP3 for: eight
# 🔊 Generating MP3 for: five
# 🔊 Generating MP3 for: follow
# 🔊 Generating MP3 for: forward
# 🔊 Generating MP3 for: four
# 🔊 Generating MP3 for: go
# 🔊 Generating MP3 for: happy
# 🔊 Generating MP3 for: house
# 🔊 Generating MP3 for: learn
# 🔊 Generating MP3 for: left
# 🔊 Generating MP3 for: marvin
# 🔊 Generating MP3 for: nine
# 🔊 Generating MP3 for: no
# 🔊 Generating MP3 for: off
# 🔊 Generating MP3 for: on
# 🔊 Generating MP3 for: one
# 🔊 Generating MP3 for: right
# 🔊 Generating MP3 for: seven
# 🔊 Generating MP3 for: six
# 🔊 Generating MP3 for: stop
# 🔊 Generating MP3 for: three
# 🔊 Generating MP3 for: tree
# 🔊 Generating MP3 for: two
# 🔊 Generating MP3 for: up
# 🔊 Generating MP3 for: visual
# 🔊 Generating MP3 for: wow
# 🔊 Generating MP3 for: yes
# 🔊 Generating MP3 for: zero
# ...

# %%
# Out:
# 🎵 Converting backward.mp3 to WAV...
# C:\Users\naikg\anaconda3new\Lib\site-packages\pydub\utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 16
#      13         wav_path = os.path.join(output_dir, filename.replace(".mp3", ".wav"))
#      15         print(f"🎵 Converting {filename} to WAV...")
# ---> 16         audio = AudioSegment.from_mp3(mp3_path)
#      17         audio.export(wav_path, format="wav")
#      19 print("\n✅ All MP3 files converted to WAV in 'keyword_samples_wav/'.")
#
# File ~\anaconda3new\Lib\site-packages\pydub\audio_segment.py:796, in AudioSegment.from_mp3(cls, file, parameters)
#     794 @classmethod
# ...

# %% [markdown]
# Good morning! Today, we are going on an adventure with my AI assistant. Let’s begin!
#
# Let's start by going forward in our learning journey. You can go backward if you want, but progress is always ahead. I saw a beautiful bird flying near my house today. Its feathers were colorful, and it sang a lovely song. My cat was sitting near the window, watching the birds outside with great curiosity. Suddenly, a dog started barking loudly, making my cat jump back in surprise.
#
# The ball rolled down the hill, and I had to chase it before it disappeared into the bushes. Running after it was fun, but also a little tiring. I can count to ten: one, two, three, four, five, six, seven, eight, nine, ten. Numbers are fascinating, and they help us understand the world around us. I will give you five reasons to love technology: it makes life easier, helps us learn, connects people, entertains us, and improves health.
#
# Are you ready to follow my instructions? You can move forward by listening carefully. Counting again: one, two, three, four. Let's go on a journey to explore new ideas. Feeling happy today? I hope so! I live in a big house with a smart assistant that helps with daily tasks.
#
# Turn left at the next corner to reach the park, where children play and birds sing. My robot friend is named Marvin, and he loves solving problems. I have counted nine apples in my basket. You can say no if you don’t want to participate.
#
# Please turn the lights off before leaving, and then turn them back on when you return. One, two, three, let’s go! If you agree, say yes! Can you count from one to zero backward?
#
# Today is a wonderful day to learn something new. The sun is shining, and the sky is a bright shade of blue. I hear the sound of laughter outside. My friends are playing a game of tag in the yard. Running, jumping, and laughing, they enjoy the moment.
#
# I pick up a book and begin reading an exciting story. The characters go on a grand adventure, much like we are doing today. Learning never stops, and every day brings a new experience. The more I read, the more I discover. Books are like portals to different worlds, full of knowledge and imagination.
#
# Look at the clock! Time is moving forward, just like we are. Every second counts, so let's make the most of it. I wonder what exciting things will happen next. Maybe I will learn a new word today or discover a fun fact about space.
#
# Do you know there are eight planets in our solar system? Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune. Each one is unique, just like us. Learning about space makes me feel like an explorer traveling through the universe.
#
# I love counting. Let’s count again: one, two, three, four, five, six, seven, eight. Numbers are everywhere—in clocks, books, and even nature.
#
# The leaves rustle as the wind blows gently. I take a deep breath and enjoy the fresh air. Life is full of small moments that bring joy. Let’s appreciate them together. What’s something you’re grateful for today?
#
# Now, let’s take another step forward in our adventure. There is always something new to explore!

# %%
It was a bright morning, and Alex and Jamie were sitting on a bench in the park, deep in conversation. The air was filled with the chirping of birds, and the rustling of leaves created a soothing backdrop. A third person, an observer named Sam, watched them from a distance, intrigued by their animated discussion.

